# %% [markdown]
# ## Name	:Sankalp Laxman Khatake
# ## Roll	no	:	23107064
# ## Batch	:	AI-DS(D)
# ## Assignment	10	:Implement ARIMA in python.

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as ans

# %%
df=pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.hist('SepalLengthCm')
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>]], dtype=object)

# %%
df.hist('PetalLengthCm')
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}>]], dtype=object)

# %%
df.hist('SepalWidthCm')
# Out:
# array([[<Axes: title={'center': 'SepalWidthCm'}>]], dtype=object)

# %%
df.hist('PetalWidthCm',color='red')
# Out:
# array([[<Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
df.hist('SepalWidthCm' ,color="black")
# Out:
# array([[<Axes: title={'center': 'SepalWidthCm'}>]], dtype=object)

# %%
plt.hist(df['SepalLengthCm'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.xlabel(df["SepalLengthCm"])
# Out:
# Text(0.5, 0, '0      5.1\n1      4.9\n2      4.7\n3      4.6\n4      5.0\n      ... \n145    6.7\n146    6.3\n147    6.5\n148    6.2\n149    5.9\nName: SepalLengthCm, Length: 150, dtype: float64')

# %%
plt.hist(df["SepalLengthCm"])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
 plt.hist(df["SepalLengthCm"])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["PetalLengthCm"])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['PetalWidthCm'])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df["SepalWidthCm"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a5d469a7b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a5d27f22d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a5d46b85f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a5d27f3530>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a5d4322de0>],
#  'means': []}

# %%
plt.boxplot(df["PetalWidthCm"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a5d42a8b00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a5d42aba40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a5d42aaab0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a5d42ab380>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a5d42ab800>],
#  'means': []}

# %%
ans.boxplot(df["SepalWidthCm"])
# Out:
# <Axes: ylabel='SepalWidthCm'>

# %%
ans.boxplot(df["PetalWidthCm"])
# Out:
# <Axes: ylabel='PetalWidthCm'>

# %%
ans.boxplot(df)
# Out:
# <Axes: >

# %%
ans.pairplot(df,hue='Species')

# %%
df2=pd.read_csv("titanic.csv")

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ans.boxplot(x=df2["Sex"],y=df2["Age"],hue=df2["Survived"])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
 ans.scatterplot(x=df2["Age"],y=df2["Fare"])
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
ans.histplot(df2["Fare"])
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
ans.distplot(df2["Fare"])
# Out:
# C:\Users\SANKALP\AppData\Local\Temp\ipykernel_13732\1537749543.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ans.distplot(df2["Fare"])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
ans.boxplot(df2["Fare"])
# Out:
# <Axes: ylabel='Fare'>

# %%
ans.jointplot(x=df2["Age"],y=df2["Fare"],hue=df2["Survived"])

# %%
ans.pairplot(df2)

# %%
ans.barplot(x=df2["Sex"],y=df2["Age"],color="ed")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
ans.violinplot(x=df2["Sex"],y=df2["Age"],hue=df2["Survived"])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
ans.stripplot(x=df2["Sex"],y=df2["Age"],hue=df2["SibSp"])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
ans.countplot(x=df2["Sex"])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
ans.stripplot(x=df2["Sex"],y=df2["Age"],hue=df2["Survived"])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
ans.swarmplot(x=df2["Sex"],y=df2["Age"],hue=df2["Survived"])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>
