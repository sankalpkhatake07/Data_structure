# %% [markdown]
# # Assignment No:02

# %% [markdown]
# #### Name:Khatake Sankalp Laxman
# #### Batch : D
# #### Class:S.Y-A
# #### EPR No: EN23107064

# %%
import pandas as pd

# %%
df= pd.read_csv('sk.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df['age'].mean()
# Out:
# 38.64358543876172

# %%
df['age'].where(df['age']>30)
# Out:
# 0         NaN
# 1        38.0
# 2         NaN
# 3        44.0
# 4         NaN
#          ...
# 48837     NaN
# 48838    40.0
# 48839    58.0
# 48840     NaN
# 48841    52.0
# Name: age, Length: 48842, dtype: float64

# %%
df.where(df['age']>50)
# Out:
#         age     workclass    fnlwgt education  educational-num  \
# 0       NaN           NaN       NaN       NaN              NaN
# 1       NaN           NaN       NaN       NaN              NaN
# 2       NaN           NaN       NaN       NaN              NaN
# 3       NaN           NaN       NaN       NaN              NaN
# 4       NaN           NaN       NaN       NaN              NaN
# ...     ...           ...       ...       ...              ...
# 48837   NaN           NaN       NaN       NaN              NaN
# 48838   NaN           NaN       NaN       NaN              NaN
# 48839  58.0       Private  151910.0   HS-grad              9.0
# 48840   NaN           NaN       NaN       NaN              NaN
# 48841  52.0  Self-emp-inc  287927.0   HS-grad              9.0
#
#            marital-status       occupation relationship   race  gender  \
# 0                     NaN              NaN          NaN    NaN     NaN
# ...

# %%
df.where(df['age']>50).dropna()
# Out:
#         age         workclass    fnlwgt    education  educational-num  \
# 7      63.0  Self-emp-not-inc  104626.0  Prof-school             15.0
# 9      55.0           Private  104996.0      7th-8th              4.0
# 10     65.0           Private  184454.0      HS-grad              9.0
# 13     58.0                 ?  299831.0      HS-grad              9.0
# 22     72.0                 ?  132015.0      7th-8th              4.0
# ...     ...               ...       ...          ...              ...
# 48823  72.0                 ?  129912.0      HS-grad              9.0
# 48829  65.0  Self-emp-not-inc   99359.0  Prof-school             15.0
# 48835  53.0           Private  321865.0      Masters             14.0
# 48839  58.0           Private  151910.0      HS-grad              9.0
# 48841  52.0      Self-emp-inc  287927.0      HS-grad              9.0
#
#            marital-status         occupation   relationship   race  gender  \
# ...

# %%
df.where(df['income']>'50K').count()
# Out:
# age                48842
# workclass          48842
# fnlwgt             48842
# education          48842
# educational-num    48842
# marital-status     48842
# occupation         48842
# relationship       48842
# race               48842
# gender             48842
# capital-gain       48842
# capital-loss       48842
# hours-per-week     48842
# native-country     48842
# income             48842
# dtype: int64

# %%
df.groupby(['age']).min()
# Out:
#     workclass  fnlwgt education  educational-num         marital-status  \
# age
# 17          ?   19752      10th                3     Married-civ-spouse
# 18          ?   20057      10th                3               Divorced
# 19          ?   20469      10th                1               Divorced
# 20          ?   19410      10th                1               Divorced
# 21          ?   20728      10th                1               Divorced
# ..        ...     ...       ...              ...                    ...
# 86    Private  149912   Masters               14          Never-married
# 87          ?   90338   HS-grad                9  Married-spouse-absent
# 88    Private   30102      11th                4               Divorced
# 89          ?   29106      10th                6     Married-civ-spouse
# 90          ?   39824      10th                2               Divorced
#
#        occupation   relationship                race  gender  capital-gain  \
# age
# ...

# %%
df.groupby(['age','workclass','fnlwgt','education','educational-num']).count().head().tail()
# Out:
#                                                 marital-status  occupation  \
# age workclass fnlwgt education educational-num
# 17  ?         27251  11th      7                             1           1
#               34019  10th      6                             1           1
#               34088  12th      8                             1           1
#               34505  11th      7                             1           1
#               35603  11th      7                             1           1
#
#                                                 relationship  race  gender  \
# age workclass fnlwgt education educational-num
# 17  ?         27251  11th      7                           1     1       1
#               34019  10th      6                           1     1       1
#               34088  12th      8                           1     1       1
#               34505  11th      7                           1     1       1
# ...

# %%
df.groupby(['age']).sum()
# Out:
#                                              workclass     fnlwgt  \
# age
# 17   Private?PrivatePrivate?PrivatePrivatePrivatePr...  106598922
# 18   ?PrivatePrivatePrivatePrivatePrivatePrivatePri...  166728967
# 19   PrivatePrivatePrivatePrivatePrivatePrivatePriv...  215777445
# 20   State-govPrivateState-govPrivateFederal-govPri...  220459159
# 21   PrivatePrivatePrivatePrivatePrivatePrivate?Pri...  219449363
# ..                                                 ...        ...
# 86                                             Private     149912
# 87                                           Private??     331207
# 88   Self-emp-not-incSelf-emp-not-incPrivateSelf-em...     897244
# 89                                            Private?     181945
# 90   PrivateSelf-emp-not-incPrivatePrivateSelf-emp-...    9369040
#
#                                              education  educational-num  \
# age
# 17   10th10th11th10th11th11th11th11th7th-8th11th11t...             3978
# ...

# %%
df.groupby(['income']).sum()
# Out:
#             age                                          workclass  \
# income
# <=50K   1369986  PrivatePrivate?Private?PrivatePrivateFederal-g...
# >50K     517444  Local-govPrivateSelf-emp-not-incPrivatePrivate...
#
#             fnlwgt                                          education  \
# income
# <=50K   7060920057  11thHS-gradSome-college10thHS-gradSome-college...
# >50K    2202655605  Assoc-acdmSome-collegeProf-schoolHS-gradHS-gra...
#
#         educational-num                                     marital-status  \
# income
# <=50K            356632  Never-marriedMarried-civ-spouseNever-marriedNe...
# >50K             135602  Married-civ-spouseMarried-civ-spouseMarried-ci...
#
#                                                occupation  \
# income
# <=50K   Machine-op-inspctFarming-fishing?Other-service...
# >50K    Protective-servMachine-op-inspctProf-specialty...
#
#                                              relationship  \
# income
# ...

# %%
df.groupby(['income']).count()
# Out:
#           age  workclass  fnlwgt  education  educational-num  marital-status  \
# income
# <=50K   37155      37155   37155      37155            37155           37155
# >50K    11687      11687   11687      11687            11687           11687
#
#         occupation  relationship   race  gender  capital-gain  capital-loss  \
# income
# <=50K        37155         37155  37155   37155         37155         37155
# >50K         11687         11687  11687   11687         11687         11687
#
#         hours-per-week  native-country
# income
# <=50K            37155           37155
# >50K             11687           11687

# %%
df.groupby(['income']).max()
# Out:
#         age    workclass   fnlwgt     education  educational-num  \
# income
# <=50K    90  Without-pay  1490400  Some-college               16
# >50K     90  Without-pay  1226583  Some-college               16
#
#        marital-status        occupation relationship   race gender  \
# income
# <=50K         Widowed  Transport-moving         Wife  White   Male
# >50K          Widowed  Transport-moving         Wife  White   Male
#
#         capital-gain  capital-loss  hours-per-week native-country
# income
# <=50K          41310          4356              99     Yugoslavia
# >50K           99999          3683              99     Yugoslavia

# %%
df.groupby(['income']).min()
# Out:
#         age workclass  fnlwgt education  educational-num marital-status  \
# income
# <=50K    17         ?   12285      10th                1       Divorced
# >50K     19         ?   13769      10th                1       Divorced
#
#        occupation relationship                race  gender  capital-gain  \
# income
# <=50K           ?      Husband  Amer-Indian-Eskimo  Female             0
# >50K            ?      Husband  Amer-Indian-Eskimo  Female             0
#
#         capital-loss  hours-per-week native-country
# income
# <=50K              0               1              ?
# >50K               0               1              ?

# %%
df.groupby(['income','age','occupation']).count().head()
# Out:
#                             workclass  fnlwgt  education  educational-num  \
# income age occupation
# <=50K  17  ?                       99      99         99               99
#            Adm-clerical            39      39         39               39
#            Craft-repair            18      18         18               18
#            Exec-managerial          3       3          3                3
#            Farming-fishing         17      17         17               17
#
#                             marital-status  relationship  race  gender  \
# income age occupation
# <=50K  17  ?                            99            99    99      99
#            Adm-clerical                 39            39    39      39
#            Craft-repair                 18            18    18      18
#            Exec-managerial               3             3     3       3
#            Farming-fishing              17            17    17      17
#
# ...

# %%
df.groupby(['income','age','occupation']).sum()
# Out:
#                                                                     workclass  \
# income age occupation
# <=50K  17  ?                ???????????????Never-worked???????????????????...
#            Adm-clerical     PrivatePrivatePrivateSelf-emp-incPrivatePrivat...
#            Craft-repair     PrivatePrivatePrivatePrivatePrivatePrivatePriv...
#            Exec-managerial                              PrivatePrivatePrivate
#            Farming-fishing  PrivatePrivateSelf-emp-not-incPrivateLocal-gov...
# ...                                                                       ...
# >50K   90  Adm-clerical                                               Private
#            Craft-repair                                      Local-govPrivate
#            Exec-managerial                     PrivateLocal-govPrivatePrivate
#            Prof-specialty                      Self-emp-not-incPrivatePrivate
#            Sales                                               PrivatePrivate
#
# ...

# %%
df.groupby(['income','gender']).count()
# Out:
#                  age  workclass  fnlwgt  education  educational-num  \
# income gender
# <=50K  Female  14423      14423   14423      14423            14423
#        Male    22732      22732   22732      22732            22732
# >50K   Female   1769       1769    1769       1769             1769
#        Male     9918       9918    9918       9918             9918
#
#                marital-status  occupation  relationship   race  capital-gain  \
# income gender
# <=50K  Female           14423       14423         14423  14423         14423
#        Male             22732       22732         22732  22732         22732
# >50K   Female            1769        1769          1769   1769          1769
#        Male              9918        9918          9918   9918          9918
#
#                capital-loss  hours-per-week  native-country
# income gender
# <=50K  Female         14423           14423           14423
#        Male           22732           22732           22732
# ...

# %%
df.groupby(['income','age','occupation']).max()
# Out:
#                                    workclass  fnlwgt     education  \
# income age occupation
# <=50K  17  ?                    Never-worked  806316  Some-college
#            Adm-clerical     Self-emp-not-inc  413557  Some-college
#            Craft-repair         Self-emp-inc  323164  Some-college
#            Exec-managerial           Private  311288       HS-grad
#            Farming-fishing         State-gov  368700       HS-grad
# ...                                      ...     ...           ...
# >50K   90  Adm-clerical              Private  197613       HS-grad
#            Craft-repair              Private  188242       HS-grad
#            Exec-managerial           Private  227796       Masters
#            Prof-specialty   Self-emp-not-inc  206667   Prof-school
#            Sales                     Private  149069     Bachelors
#
#                             educational-num      marital-status  \
# income age occupation
# ...

# %%
df.groupby(['income','age','occupation']).min()
# Out:
#                               workclass  fnlwgt   education  educational-num  \
# income age occupation
# <=50K  17  ?                          ?   27251        10th                4
#            Adm-clerical     Federal-gov   29078        10th                6
#            Craft-repair       Local-gov   61838        10th                4
#            Exec-managerial      Private   23856        11th                7
#            Farming-fishing    Local-gov   32607        10th                4
# ...                                 ...     ...         ...              ...
# >50K   90  Adm-clerical         Private  197613     HS-grad                9
#            Craft-repair       Local-gov  175491     HS-grad                9
#            Exec-managerial    Local-gov   51744  Assoc-acdm               12
#            Prof-specialty       Private   87372     Masters               14
#            Sales                Private   46786  Assoc-acdm               12
#
# ...

# %%
df.groupby(['income','age']).count()
# Out:
#             workclass  fnlwgt  education  educational-num  marital-status  \
# income age
# <=50K  17         595     595        595              595             595
#        18         862     862        862              862             862
#        19        1050    1050       1050             1050            1050
#        20        1112    1112       1112             1112            1112
#        21        1090    1090       1090             1090            1090
# ...               ...     ...        ...              ...             ...
# >50K   83           2       2          2                2               2
#        84           1       1          1                1               1
#        85           1       1          1                1               1
#        88           1       1          1                1               1
#        90          13      13         13               13              13
#
#             occupation  relationship  race  gender  capital-gain  \
# ...

# %%
df['age'].sum()/df['age'].count()
# Out:
# 38.64358543876172

# %%
df['education'].value_counts().count()
# Out:
# 16

# %%
df['age'].value_counts().count()
# Out:
# 74

# %%
df['occupation'].value_counts().count()
# Out:
# 15

# %%
df['marital-status'].value_counts().count()
# Out:
# 7

# %%
df['education'].value_counts()
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
df['age'].median()
# Out:
# 37.0

# %%
df['income'].value_counts()
# Out:
# income
# <=50K    37155
# >50K     11687
# Name: count, dtype: int64

# %%
a=df['age'].sum()

# %%
b=df['age'].count()

# %%
c=a/b

# %%
c
# Out:
# 38.64358543876172

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df['occupation'].count()
# Out:
# 48842

# %%
df['age'].count()
# Out:
# 48842

# %%
df['age'].mode()
# Out:
# 0    36
# Name: age, dtype: int64

# %%
df['marital-status'].value_counts()
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df.count()
# Out:
# age                48842
# workclass          48842
# fnlwgt             48842
# education          48842
# educational-num    48842
# marital-status     48842
# occupation         48842
# relationship       48842
# race               48842
# gender             48842
# capital-gain       48842
# capital-loss       48842
# hours-per-week     48842
# native-country     48842
# income             48842
# dtype: int64

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.size
# Out:
# 732630

# %%
df.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# ...

# %%
df['age'].max()
# Out:
# 90

# %%
df['age'].min()
# Out:
# 17

# %%
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
df['fnlwgt'].min()
# Out:
# 12285

# %%
df['fnlwgt'].max()
# Out:
# 1490400

# %%
df['fnlwgt'].count()
# Out:
# 48842

# %%
df['fnlwgt'].value_counts()
# Out:
# fnlwgt
# 203488    21
# 190290    19
# 120277    19
# 125892    18
# 126569    18
#           ..
# 188488     1
# 285290     1
# 293579     1
# 114874     1
# 257302     1
# Name: count, Length: 28523, dtype: int64

# %%
df.ndim
# Out:
# 2

# %%
df.head
# Out:
# <bound method NDFrame.head of        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm               12
# 48838   40       Private  154374     HS-grad                9
# 48839   58       Private  151910     HS-grad                9
# 48840   22       Private  201490     HS-grad                9
# 48841   52  Self-emp-inc  287927     HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# ...

# %%
df.notnull()
# Out:
#         age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      True       True    True       True             True            True
# 1      True       True    True       True             True            True
# 2      True       True    True       True             True            True
# 3      True       True    True       True             True            True
# 4      True       True    True       True             True            True
# ...     ...        ...     ...        ...              ...             ...
# 48837  True       True    True       True             True            True
# 48838  True       True    True       True             True            True
# 48839  True       True    True       True             True            True
# 48840  True       True    True       True             True            True
# 48841  True       True    True       True             True            True
#
# ...

# %%
df.isnull()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
df.sort_index()
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df['workclass'].sort_index()
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 4                   ?
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 48842, dtype: object

# %%
df['fnlwgt'].sort_index()
# Out:
# 0        226802
# 1         89814
# 2        336951
# 3        160323
# 4        103497
#           ...
# 48837    257302
# 48838    154374
# 48839    151910
# 48840    201490
# 48841    287927
# Name: fnlwgt, Length: 48842, dtype: int64
